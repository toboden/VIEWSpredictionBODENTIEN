# %%
import os
from joblib import load
import numpy as np

# %% [markdown]
# # NBinom

# %%
user_dir = os.path.expanduser('~')

file_path = os.path.join(user_dir, 'iCloudDrive\\VIEWS Joblib Predicitons\\Baseline', 'FinalTask2_baseline_predct_nbinomWmax24.joblib')
loaded_vars_baseline = load(file_path)

task2_baseline_list = loaded_vars_baseline[0] # crps averages for all datasets
w_minimization_list = loaded_vars_baseline[1] # contains the minimal w's for the different baselines for each year and country
baseline_prediction_list = loaded_vars_baseline[2] # predictions with the minimal w's for each dataset and country
baseline1_average_crps = loaded_vars_baseline[3] # mean CRPS from the baseline_prediction_list
baseline2_average_crps = loaded_vars_baseline[4] # ""
baseline3_average_crps = loaded_vars_baseline[5]
baseline4_average_crps = loaded_vars_baseline[6]

print('Overall CRPS NBinom, max. w = 24')
print('baseline 1: ' + str(np.round(baseline1_average_crps, decimals = 4)))
print('baseline 2: ' + str(np.round(baseline2_average_crps, decimals = 4)))
print('baseline 3: ' + str(np.round(baseline3_average_crps, decimals = 4)))
print('baseline 4: ' + str(np.round(baseline4_average_crps, decimals = 4)))
# Out:
# Overall CRPS NBinom, max. w = 24
# baseline 1: 56.2833
# baseline 2: 77.1115
# baseline 3: 56.1098
# baseline 4: 69.2462

# %%
number_countries = len(baseline_prediction_list[3])
actual_years = ['2018','2019','2020','2021','2022','2023']
s_prediction_list = list(range(3, 15))

# %%
baseline1_average_crps_2018_list = []
baseline1_average_crps_2019_list = []
baseline1_average_crps_2020_list = []
baseline1_average_crps_2021_list = []
baseline1_average_crps_2022_list = []
baseline1_average_crps_2023_list = []

baseline2_average_crps_2018_list = []
baseline2_average_crps_2019_list = []
baseline2_average_crps_2020_list = []
baseline2_average_crps_2021_list = []
baseline2_average_crps_2022_list = []
baseline2_average_crps_2023_list = []

baseline3_average_crps_2018_list = []
baseline3_average_crps_2019_list = []
baseline3_average_crps_2020_list = []
baseline3_average_crps_2021_list = []
baseline3_average_crps_2022_list = []
baseline3_average_crps_2023_list = []

baseline4_average_crps_2018_list = []
baseline4_average_crps_2019_list = []
baseline4_average_crps_2020_list = []
baseline4_average_crps_2021_list = []
baseline4_average_crps_2022_list = []
baseline4_average_crps_2023_list = []

for i in range(6):
    year = actual_years[i]
    for index in range(number_countries):
        
        if year == '2018':
            baseline1_average_crps_2018_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2018_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2019':
            baseline1_average_crps_2019_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2019_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2020':
            baseline1_average_crps_2020_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2020_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2021':
            baseline1_average_crps_2021_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2021_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2022':
            baseline1_average_crps_2022_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2022_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2023':
            baseline1_average_crps_2023_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2023_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        
        for s in s_prediction_list:
            
            if year == '2018':
                baseline3_average_crps_2018_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2018_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2019':
                baseline3_average_crps_2019_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2019_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2020':
                baseline3_average_crps_2020_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2020_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2021':
                baseline3_average_crps_2021_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2021_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2022':
                baseline3_average_crps_2022_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2022_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2023':
                baseline3_average_crps_2023_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2023_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

baseline1_average_crps_2018 = np.mean(baseline1_average_crps_2018_list)
baseline1_average_crps_2019 = np.mean(baseline1_average_crps_2019_list)
baseline1_average_crps_2020 = np.mean(baseline1_average_crps_2020_list)
baseline1_average_crps_2021 = np.mean(baseline1_average_crps_2021_list)
baseline1_average_crps_2022 = np.mean(baseline1_average_crps_2022_list)
baseline1_average_crps_2023 = np.mean(baseline1_average_crps_2023_list)

baseline2_average_crps_2018 = np.mean(baseline2_average_crps_2018_list)
baseline2_average_crps_2019 = np.mean(baseline2_average_crps_2019_list)
baseline2_average_crps_2020 = np.mean(baseline2_average_crps_2020_list)
baseline2_average_crps_2021 = np.mean(baseline2_average_crps_2021_list)
baseline2_average_crps_2022 = np.mean(baseline2_average_crps_2022_list)
baseline2_average_crps_2023 = np.mean(baseline2_average_crps_2023_list)

baseline3_average_crps_2018 = np.mean(baseline3_average_crps_2018_list)
baseline3_average_crps_2019 = np.mean(baseline3_average_crps_2019_list)
baseline3_average_crps_2020 = np.mean(baseline3_average_crps_2020_list)
baseline3_average_crps_2021 = np.mean(baseline3_average_crps_2021_list)
baseline3_average_crps_2022 = np.mean(baseline3_average_crps_2022_list)
baseline3_average_crps_2023 = np.mean(baseline3_average_crps_2023_list)

baseline4_average_crps_2018 = np.mean(baseline4_average_crps_2018_list)
baseline4_average_crps_2019 = np.mean(baseline4_average_crps_2019_list)
baseline4_average_crps_2020 = np.mean(baseline4_average_crps_2020_list)
baseline4_average_crps_2021 = np.mean(baseline4_average_crps_2021_list)
baseline4_average_crps_2022 = np.mean(baseline4_average_crps_2022_list)
baseline4_average_crps_2023 = np.mean(baseline4_average_crps_2023_list)

print('Overall CRPS NB')
print('Overall CRPS baseline 1')
print('Year 2018: ' + str(np.round(baseline1_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline1_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline1_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline1_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline1_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline1_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 2')
print('Year 2018: ' + str(np.round(baseline2_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline2_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline2_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline2_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline2_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline2_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 3')
print('Year 2018: ' + str(np.round(baseline3_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline3_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline3_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline3_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline3_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline3_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 4')
print('Year 2018: ' + str(np.round(baseline4_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline4_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline4_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline4_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline4_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline4_average_crps_2023, decimals = 4)))
# Out:
# Overall CRPS NB
# Overall CRPS baseline 1
# Year 2018: 14.0835
# Year 2019: 11.1288
# Year 2020: 20.6303
# Year 2021: 76.7121
# Year 2022: 128.7378
# Year 2023: 86.407
#
# Overall CRPS baseline 2
# Year 2018: 14.0667
# Year 2019: 9.3751
# Year 2020: 21.7071
# Year 2021: 77.2958
# Year 2022: 123.9072
# Year 2023: 216.3171
#
# Overall CRPS baseline 3
# Year 2018: 14.0835
# Year 2019: 11.1288
# Year 2020: 20.6397
# Year 2021: 76.5768
# Year 2022: 125.6159
# Year 2023: 88.6143
#
# Overall CRPS baseline 4
# Year 2018: 13.7216
# Year 2019: 9.1845
# Year 2020: 22.0469
# Year 2021: 77.5606
# Year 2022: 123.8448
# Year 2023: 169.119

# %% [markdown]
# # Hurdle

# %%
user_dir = os.path.expanduser('~')
file_path = os.path.join(user_dir, 'iCloudDrive\\VIEWS Joblib Predicitons\\Baseline', 'FinalTask2_baseline_predct_hurdleWmax24.joblib')
loaded_vars_baseline = load(file_path)

task2_baseline_list = loaded_vars_baseline[0] # crps averages for all datasets
w_minimization_list = loaded_vars_baseline[1] # contains the minimal w's for the different baselines for each year and country
baseline_prediction_list = loaded_vars_baseline[2] # predictions with the minimal w's for each dataset and country
baseline1_average_crps = loaded_vars_baseline[3] # mean CRPS from the baseline_prediction_list
baseline2_average_crps = loaded_vars_baseline[4] # ""
baseline3_average_crps = loaded_vars_baseline[5]
baseline4_average_crps = loaded_vars_baseline[6]

print('Overall CRPS Hurdle, max. w = 24')
print('baseline 1: ' + str(np.round(baseline1_average_crps, decimals = 4)))
print('baseline 2: ' + str(np.round(baseline2_average_crps, decimals = 4)))
print('baseline 3: ' + str(np.round(baseline3_average_crps, decimals = 4)))
print('baseline 4: ' + str(np.round(baseline4_average_crps, decimals = 4)))
# Out:
# Overall CRPS Hurdle, max. w = 24
# baseline 1: 56.6621
# baseline 2: 77.4704
# baseline 3: 58.6499
# baseline 4: 74.6854

# %%
baseline1_average_crps_2018_list = []
baseline1_average_crps_2019_list = []
baseline1_average_crps_2020_list = []
baseline1_average_crps_2021_list = []
baseline1_average_crps_2022_list = []
baseline1_average_crps_2023_list = []

baseline2_average_crps_2018_list = []
baseline2_average_crps_2019_list = []
baseline2_average_crps_2020_list = []
baseline2_average_crps_2021_list = []
baseline2_average_crps_2022_list = []
baseline2_average_crps_2023_list = []

baseline3_average_crps_2018_list = []
baseline3_average_crps_2019_list = []
baseline3_average_crps_2020_list = []
baseline3_average_crps_2021_list = []
baseline3_average_crps_2022_list = []
baseline3_average_crps_2023_list = []

baseline4_average_crps_2018_list = []
baseline4_average_crps_2019_list = []
baseline4_average_crps_2020_list = []
baseline4_average_crps_2021_list = []
baseline4_average_crps_2022_list = []
baseline4_average_crps_2023_list = []

for i in range(6):
    year = actual_years[i]
    for index in range(number_countries):
        
        if year == '2018':
            baseline1_average_crps_2018_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2018_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2019':
            baseline1_average_crps_2019_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2019_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2020':
            baseline1_average_crps_2020_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2020_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2021':
            baseline1_average_crps_2021_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2021_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2022':
            baseline1_average_crps_2022_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2022_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        elif year == '2023':
            baseline1_average_crps_2023_list.append(np.mean(baseline_prediction_list[0][index]['prediction'][year][0]['CRPS']))
            baseline2_average_crps_2023_list.append(np.mean(baseline_prediction_list[1][index]['prediction'][year][0]['CRPS']))
        
        for s in s_prediction_list:
            
            if year == '2018':
                baseline3_average_crps_2018_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2018_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2019':
                baseline3_average_crps_2019_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2019_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2020':
                baseline3_average_crps_2020_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2020_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2021':
                baseline3_average_crps_2021_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2021_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2022':
                baseline3_average_crps_2022_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2022_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

            elif year == '2023':
                baseline3_average_crps_2023_list.append(np.mean(baseline_prediction_list[2][index]['prediction'][year][s-3]['CRPS']))
                baseline4_average_crps_2023_list.append(np.mean(baseline_prediction_list[3][index]['prediction'][year][s-3]['CRPS']))

baseline1_average_crps_2018 = np.mean(baseline1_average_crps_2018_list)
baseline1_average_crps_2019 = np.mean(baseline1_average_crps_2019_list)
baseline1_average_crps_2020 = np.mean(baseline1_average_crps_2020_list)
baseline1_average_crps_2021 = np.mean(baseline1_average_crps_2021_list)
baseline1_average_crps_2022 = np.mean(baseline1_average_crps_2022_list)
baseline1_average_crps_2023 = np.mean(baseline1_average_crps_2023_list)

baseline2_average_crps_2018 = np.mean(baseline2_average_crps_2018_list)
baseline2_average_crps_2019 = np.mean(baseline2_average_crps_2019_list)
baseline2_average_crps_2020 = np.mean(baseline2_average_crps_2020_list)
baseline2_average_crps_2021 = np.mean(baseline2_average_crps_2021_list)
baseline2_average_crps_2022 = np.mean(baseline2_average_crps_2022_list)
baseline2_average_crps_2023 = np.mean(baseline2_average_crps_2023_list)

baseline3_average_crps_2018 = np.mean(baseline3_average_crps_2018_list)
baseline3_average_crps_2019 = np.mean(baseline3_average_crps_2019_list)
baseline3_average_crps_2020 = np.mean(baseline3_average_crps_2020_list)
baseline3_average_crps_2021 = np.mean(baseline3_average_crps_2021_list)
baseline3_average_crps_2022 = np.mean(baseline3_average_crps_2022_list)
baseline3_average_crps_2023 = np.mean(baseline3_average_crps_2023_list)

baseline4_average_crps_2018 = np.mean(baseline4_average_crps_2018_list)
baseline4_average_crps_2019 = np.mean(baseline4_average_crps_2019_list)
baseline4_average_crps_2020 = np.mean(baseline4_average_crps_2020_list)
baseline4_average_crps_2021 = np.mean(baseline4_average_crps_2021_list)
baseline4_average_crps_2022 = np.mean(baseline4_average_crps_2022_list)
baseline4_average_crps_2023 = np.mean(baseline4_average_crps_2023_list)

print('Overall CRPS Hurdle')
print('Overall CRPS baseline 1')
print('Year 2018: ' + str(np.round(baseline1_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline1_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline1_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline1_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline1_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline1_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 2')
print('Year 2018: ' + str(np.round(baseline2_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline2_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline2_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline2_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline2_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline2_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 3')
print('Year 2018: ' + str(np.round(baseline3_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline3_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline3_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline3_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline3_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline3_average_crps_2023, decimals = 4)))
print()

print('Overall CRPS baseline 4')
print('Year 2018: ' + str(np.round(baseline4_average_crps_2018, decimals = 4)))
print('Year 2019: ' + str(np.round(baseline4_average_crps_2019, decimals = 4)))
print('Year 2020: ' + str(np.round(baseline4_average_crps_2020, decimals = 4)))
print('Year 2021: ' + str(np.round(baseline4_average_crps_2021, decimals = 4)))
print('Year 2022: ' + str(np.round(baseline4_average_crps_2022, decimals = 4)))
print('Year 2023: ' + str(np.round(baseline4_average_crps_2023, decimals = 4)))
# Out:
# Overall CRPS Hurdle
# Overall CRPS baseline 1
# Year 2018: 14.3604
# Year 2019: 11.1257
# Year 2020: 20.6818
# Year 2021: 77.0118
# Year 2022: 128.8422
# Year 2023: 87.9506
#
# Overall CRPS baseline 2
# Year 2018: 14.2197
# Year 2019: 9.3607
# Year 2020: 21.7121
# Year 2021: 79.1063
# Year 2022: 123.9835
# Year 2023: 216.4398
#
# Overall CRPS baseline 3
# Year 2018: 15.1073
# Year 2019: 11.1257
# Year 2020: 20.6813
# Year 2021: 76.8485
# Year 2022: 124.7887
# Year 2023: 103.3479
#
# Overall CRPS baseline 4
# Year 2018: 13.9044
# Year 2019: 9.1603
# Year 2020: 22.1376
# Year 2021: 78.4008
# Year 2022: 124.0102
# Year 2023: 200.4994
